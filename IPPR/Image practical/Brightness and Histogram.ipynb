# %%
#HOW to change brightness of Image

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np 
  
# Load the image 
#image = cv2.imread('D://SJC//Image Processing//images//image1.jpg') 
image = cv2.imread("C://Users//IT//Desktop//IMG_20250210_103500_1.jpg")
#Plot the original image 
plt.subplot(1, 2, 1) 
plt.title("Original") 
plt.imshow(image) 
  
# Adjust the brightness and contrast 
# Adjusts the brightness by adding 10 to each pixel value 
brightness = 3
# Adjusts the contrast by scaling the pixel values by 2.3 
contrast = 2.3  
image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness) 
  
#Save the image 
cv2.imwrite('modified_image.jpg', image2) 
#Plot the contrast image 
plt.subplot(1, 2, 2) 
plt.title("Brightness & contrast") 
plt.imshow(image2) 
plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np 
  
# Load the image 
image = cv2.imread('D://SJC//Image Processing//images//image2.jpg') 
  
#Plot the original image 
plt.subplot(1, 2, 1) 
plt.title("Original") 
plt.imshow(image) 
  
# Adjust the brightness and contrast 
# Adjusts the brightness by adding 10 to each pixel value 
brightness = 10 
# Adjusts the contrast by scaling the pixel values by 2.3 
contrast = 2.3  
image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness) 
  
#Save the image 
cv2.imwrite('modified_image.jpg', image2) 
#Plot the contrast image 
plt.subplot(1, 2, 2) 
plt.title("Brightness & contrast") 
plt.imshow(image2) 
plt.show()

# %%
import cv2 
img = cv2.imread('D://SJC//Image Processing//images//image2.jpg')
alpha = 1.5 # Increase brightness
beta = 50 # Increase contrast
adjusted = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

# Display the adjusted image
cv2.imshow('Adjusted Image', adjusted)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import matplotlib.pyplot as plt 

img = cv2.imread('D://SJC//Image Processing//images//image2.jpg')
cv2.imshow(' Image', img)
plt.subplot(1, 2, 1) 
plt.title("Image") 
plt.imshow(img) 
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Understanding histograms using python
import cv2
import matplotlib.pyplot as plt
import numpy as np 

# Load the image
img = cv2.imread('D://SJC//Image Processing//images//image2.jpg', 0)
  
 

# Calculate the histogram
hist, bins = np.histogram(img.ravel(), 256, [0,256])
# Plot the histogram
plt.hist(img.ravel(), 256, [0, 256])
 
plt.show()
